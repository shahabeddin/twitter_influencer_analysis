# %%
#!pip install tweepy

# %%
# !pip install visJS2jupyter

# %%
# !pip install py2cytoscape

# %%
# !pip install networkx

# %%
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
import networkx as nx

# %%
from visJS2jupyter import visJS_module

# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
import tweepy

# %%
import keys

# %%
consumer_key = keys.consumer_key
consumer_secret = keys.consumer_secret
access_token = keys.access_token
access_token_secret = keys.access_token_secret

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %% [markdown]
# ### Test API

# %%
# # Using the API object to get tweets from your timeline, and storing it in a variable called public_tweets
# public_tweets = api.home_timeline(count=5)
# # foreach through all tweets pulled
# for i,tweet in enumerate(public_tweets):
#    # printing the text stored inside the tweet object
#    print i,tweet.text

# %%
# tweet._json

# %% [markdown]
# OK it works!

# %% [markdown]
# ## Q: can we get 1 month of home tweets?

# %%
# start_date = "2017-08-01"
ht1wk=api.home_timeline(count=200)
last_id = ht1wk[-1].id
while True:
    t=api.home_timeline(count=200, max_id=last_id-1)
    if not t:
        break
    last_id = t[-1].id
    ht1wk.extend(t)
    print len(ht1wk)
# Out:
# 399
# 599
# 799
# 811

# %%
len(ht1wk)
# Out:
# 811

# %%
latest = ht1wk[0]

# %%
latest.created_at
# Out:
# datetime.datetime(2017, 9, 8, 23, 47, 8)

# %%
oldest = ht1wk[-1]

# %%
oldest.created_at
# Out:
# datetime.datetime(2017, 8, 5, 19, 15, 22)

# %% [markdown]
# ## Q: let's look at Donald Trupm (DT) account

# %%
r=api.search_users("realDonaldTrump")

# %%
r[0].screen_name
# Out:
# u'realDonaldTrump'

# %%
dt=r[0]

# %%
dt.description
# Out:
# u'45th President of the United States of America\U0001f1fa\U0001f1f8'

# %% [markdown]
# ### Q: Let's get his latest tweet

# %%
dt_tweets=api.user_timeline(dt.screen_name)

# %%
dt_latest_tweet = dt_tweets[0]

# %%
dt_latest_tweet.text
# Out:
# u'During my trip to Saudi Arabia, I spoke to the leaders of more than 50 Arab &amp; Muslim nations about the need to conf\u2026 https://t.co/BYdTMUEWcd'

# %%
dt_latest_tweet.favorite_count
# Out:
# 16918

# %%
dt_latest_tweet.retweet_count
# Out:
# 4429

# %%
rt=dt_latest_tweet.retweets()

# %%
rt[0].author.screen_name
# Out:
# u'DubeAnjle'

# %% [markdown]
# ### Q: Let's look at his followers

# %%
f=dt.followers()

# %%
len(f)
# Out:
# 20

# %%
print [i.screen_name for i in f]
# Out:
# [u'canino007', u'Jose38017984', u'90Calleja', u'BlowinbandzY', u'6ZmaXTSssGMHNFL', u'FxImperium', u'Torben74', u'MohamedAli66602', u'XO43NxQ25SSyTRP', u'MarksmanCarrysU', u'xo_booms', u'JhoemPobar', u'ElenaDo71694062', u'marizhang66', u'Kaled18635131', u'TWNHmex', u'DixieHanson18', u'JcUtLxvKqt7nfNc', u'EmilyGalaxia', u'qhewjzte583']

# %%
dt.followers_count
# Out:
# 37781972

# %% [markdown]
# ### Q: Let's look at Barack Obama (BO)

# %%
r=api.search_users("BarackObama")

# %%
r[0].screen_name
# Out:
# u'BarackObama'

# %%
bo=r[0]

# %%
bo.description
# Out:
# u'Dad, husband, President, citizen.'

# %%
bo.followers_count
# Out:
# 94595673

# %%
bo.followers_count/dt.followers_count
# Out:
# 2

# %% [markdown]
# ### Q: Can we visualize the timeline as histograms of number of tweets per user?

# %%
a=Counter([t.author.screen_name for t in ht1wk])

a.most_common()
# Out:
# [(u'realDonaldTrump', 278),
#  (u'SenSanders', 95),
#  (u'SenWarren', 88),
#  (u'fashionistatalk', 86),
#  (u'HenryJEvans', 86),
#  (u'kellymcevers', 79),
#  (u'StephenAtHome', 29),
#  (u'HillaryClinton', 20),
#  (u'elizabethforma', 19),
#  (u'astorino_steven', 10),
#  (u'BarackObama', 8),
#  (u'ShahriarSh', 7),
#  (u'JZarif', 6)]

# %%
d=pd.DataFrame(a.items(), columns=["screen_name","tweet_count"])

# %%
d.set_index("screen_name", inplace=True)

# %%
d.sort_values(by="tweet_count", inplace=True)

# %%
d.plot.barh(y="tweet_count");
# Out:
# <img src="data:image/png;base64,..." width="952">

# %% [markdown]
# ### Q: transform the tweeter data format to DataFrame for easier analysis

# %%
# latest.__dict__

# %%
use_fields = ["id","created_at", "favorite_count","retweet_count","retweeted","user.screen_name","user.followers_count",
              "text"]

# %%
df=pd.DataFrame([[eval("t."+c) for c in use_fields] for t in ht1wk], columns=use_fields).set_index("id")

# %% [markdown]
# ### Top most liked tweets

# %%
df.sort_values(by="favorite_count", ascending=False).head(5)
# Out:
#                             created_at  favorite_count  retweet_count  \
# id
# 896523232098078720 2017-08-13 00:06:09         4590167        1707297
# 898261944095789056 2017-08-17 19:15:11         1631429         324677
# 896523304873238528 2017-08-13 00:06:27         1587579         502624
# 896523357272911872 2017-08-13 00:06:39         1417239         415697
# 905141484386750469 2017-09-05 18:52:01          910297         387807
#
#                    retweeted user.screen_name  user.followers_count  \
# id
# 896523232098078720     False      BarackObama              94589040
# 898261944095789056     False      BarackObama              94589040
# 896523304873238528     False      BarackObama              94589040
# 896523357272911872     False      BarackObama              94589040
# 905141484386750469     False      BarackObama              94589039
#
#                                                                  text
# id
# 896523232098078720  "No one is born hating another person because ...
# 898261944095789056  Michelle and I are thinking of the victims and...
# 896523304873238528  "People must learn to hate, and if they can le...
# 896523357272911872  "...For love comes more naturally to the human...
# 905141484386750469  To target hopeful young strivers who grew up h...

# %% [markdown]
# ### Q: plot favorite_count as a time series for specific users

# %%
ax=df.loc[df["user.screen_name"]=="realDonaldTrump"].set_index("created_at").plot(y="favorite_count",marker='.')
df.loc[df["user.screen_name"]=="SenSanders"].set_index("created_at").plot(y="favorite_count", marker='o',ax=ax)
ax.legend(["Trump's favorite_count","Sanders' favorit_count"])
# Out:
# <img src="data:image/png;base64,..." width="1003">

# %% [markdown]
# ### Q: Who has the most number of followers?

# %%
g=df[["user.screen_name","user.followers_count"]].groupby("user.screen_name").max().sort_values("user.followers_count")

# %%
g.plot.barh()
# Out:
# <img src="data:image/png;base64,..." width="956">

# %% [markdown]
# #### Log Scale

# %%
g.plot.barh(log=True)
# Out:
# <img src="data:image/png;base64,..." width="1014">

# %% [markdown]
# ### Q: create a directed graph of users (nodes: authors, edges: following)

# %%
import matplotlib as mpl
import networkx as nx
import visJS2jupyter.visJS_module

# %%
import cPickle as pickle

# %%
users={i.id:i for i in api.friends()}

# %%
g=nx.DiGraph()

# %%
g.add_nodes_from(users)

# %%
g.nodes()
# Out:
# [1916120257,
#  16303106,
#  970207298,
#  813286,
#  87823144,
#  29442313,
#  46541122,
#  2238324110,
#  40815629,
#  47813521,
#  1339835893,
#  357606935,
#  1926683448,
#  104673756,
#  2176745083,
#  197574940,
#  25073877]

# %%
user_list=g.nodes()
for n in np.random.permutation(user_list):
    if g.edges(n):
        continue
    fl=users[n].followers()
    fr=users[n].friends()
    new_users={i.id:i for i in fl+fr}
    users.update(new_users)
    g.add_nodes_from(new_users)
    print "Num. users:", len(g.nodes())
    g.add_edges_from([(n,i.id) for i in fl])
    g.add_edges_from([(i.id,n) for i in fr])
# Out:
# Num. users: 57
# Num. users: 97
# Num. users: 135
# Num. users: 175
# Num. users: 215
# Num. users: 244
# Num. users: 281
# Num. users: 319
# Num. users: 356
# Num. users: 371
# Num. users: 408
# Num. users: 444
# Num. users: 446

# %%
with open("my_twitter_network.pkl","w") as f:
    pickle.dump(g, f)

# %%
# u.friends()

# %%
users[n].screen_name
# Out:
# u'MohajeraniSayed'

# %%
user_list=users#g.nodes()
i=0
j=0
for n in user_list:
    #print n,
    if g.edges(n):
        #print "yes"
        i+=1
    else:
        #print "no"
        j+=1

print "yes:",i
print "no:",j
# Out:
# yes: 240
# no: 206

# %%
len(g.edges())
# Out:
# 462

# %%
len(g.nodes())
# Out:
# 446

# %% [markdown]
# ### Q: Analyse betweenness.

# %%
# G=nx.connected_watts_strogatz_graph(30,5,.2)
# nodes = G.nodes()
# edges = G.edges()

# # define the initial positions of the nodes using networkx's spring_layout function, and add to the nodes_dict.
# pos = nx.spring_layout(G)
# nodes_dict = [{"id":n,
#               "x":pos[n][0]*1000,
#               "y":pos[n][1]*1000} for n in nodes]
# node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges

# edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
#               "title":'test'} for i in range(len(edges))]

# visJS2jupyter.visJS_module.visjs_network(nodes_dict,edges_dict)

# %%
# # create a simple graph
# G1 = nx.connected_watts_strogatz_graph(30,5,.2)
# nodes1 = G1.nodes()
# edges1 = G1.edges()

# %%
# create a simple graph
G1 = g #nx.connected_watts_strogatz_graph(30,5,.2)
nodes1 = G1.nodes()
edges1 = G1.edges()

# %%
# cc = nx.clustering(G1)

# %%
bc = nx.betweenness_centrality(G1)

# %% [markdown]
# ##### betweenness_centrality
# Compute the shortest-path betweenness centrality for nodes.
#
# Betweenness centrality of a node `v` is the sum of the
# fraction of all-pairs shortest paths that pass through `v`
#
# math:
#
#    $$c_B(v) =\sum_{s,t \in V} \frac{\sigma(s, t|v)}{\sigma(s, t)}$$
#
# where $V$ is the set of nodes, $\sigma(s, t)$ is the number of
# shortest $(s, t)$-paths,  and $\sigma(s, t|v)$ is the number of those
# paths  passing through some  node `v` other than `s, t`.
# If $s = t$, $\sigma(s, t) = 1$, and if $v \in {s, t}$,
# $\sigma(s, t|v) = 0$.

# %%
df_bc=pd.DataFrame(data=[(users[i].screen_name, b) for i,b in sorted(bc.items(),key=lambda x:x[1], reverse=True)],
                   columns = ["screen_name","betweenness_score"]).set_index("screen_name")

# %%
df_bc.head()
# Out:
#                betweenness_score
# screen_name
# ShahriarSh              0.005345
# kymihypek               0.004241
# MansoorSB               0.003421
# shahabeddin56           0.003006
# SenSanders              0.002024

# %% [markdown]
# ### Q: Who has the highest betweenness score?

# %%
df_bc.head(20).plot.barh(y="betweenness_score", log=True)
# Out:
# <img src="data:image/png;base64,..." width="975">

# %%
degree = G1.degree()

# %%
p=nx.spring_layout(G1)

# %%
# sorted(nx.eigenvector_centrality(G1).items(),key=lambda x:x[1], reverse=True)

# %%
#nx.set_node_attributes(G1,'clustering_coefficient',cc)
nx.set_node_attributes(G1,'degree',degree)

# %%
bc_log={k:np.log(v) for (k,v) in bc.items()}

# %%
nx.set_node_attributes(G1,'betweenness_centrality',bc)

# %%
# map the betweenness centrality to the node color, using matplotlib spring_r colormap
node_to_color = visJS2jupyter.visJS_module.return_node_to_color(G1,field_to_map='betweenness_centrality',
                                                                cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

# set node initial positions using networkx's spring_layout function
pos = nx.spring_layout(G1)

nodes_dict1 = [{"id":users[n].screen_name,"color":node_to_color[n],
               "degree":np.log(users[n].followers_count), #nx.degree(G1,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000
               } for n in nodes1
              ]
node_map1 = dict(zip(nodes1,range(len(nodes1))))  # map to indices for source/target in edges
edges_dict1 = [{"source":node_map1[edges1[i][0]], "target":node_map1[edges1[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges1))]

# %%
# set some network-wide styles
visJS2jupyter.visJS_module.visjs_network(nodes_dict1,edges_dict1,
                          node_size_multiplier=5,node_size_transform = '',
                          node_color_highlight_border='red',node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',node_color_hover_background='#8BADD3',
                          node_font_size=25,edge_arrow_to=True,physics_enabled=True,edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',edge_width=3,max_velocity=15,min_velocity=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 5.0238805208462765, "title": "morisbrownwill2", "color": "rgba(256, 230, 25, 1)", "y": 642.48043557706455, "x": 679.93498010677115, "border_width": 0, "id": "morisbrownwill2"}, {"node_shape": "dot", "degree": 1.0986122886681098, "title": "jafar8085", "color": "rgba(256, 230, 25, 1)", "y": 775.96578129155114, "x": 630.16774009532662, "border_width": 0, "id": "jafar8085"}, {"node_shape": "dot", "degree": 0.0, "title": "taishahaendsch7", "color": "rgba(256, 230, 25, 1)", "y": 369.80592382174825, "x": 404.81799612682642, "border_width": 0, "id": "taishahaendsch7"}, {"node_shape": "dot", "degree": 1.3862943611198906, "title": "VinciDb2", "color": "rgba(256, 230, 25, 1)", "y": 726.89309449476775, "x": 54.246940988147792, "border_width": 0, "id": "VinciDb2"}, {"node_shape": "dot", "degree": 1.791759469228055, "title": "Ella90356363", "color": "rgba(256, 230, 25, 1)", "y": 714.93749354732506, "x": 674.0390655929981, "border_width": 0, "id": "Ella90356363"}, {"node_shape": "dot", "degree": 0.0, "title": "LukasK14156663", "color": "rgba(256, 230, 25, 1)", "y": 759.48490415688025, "x": 337.75662177393173, "border_width": 0, "id": "LukasK14156663"}, {"node_shape": "dot", "degree": 6.523562306149512, "title": "lkcckl441", "color": "rgba(256, 230, 25, 1)", "y": 771.49890159292499, "x": 577.01602533880236, "border_width": 0, "id": "lkcckl441"}, {"node_shape": "dot", "degree": -Infinity, "title": "Mohamad61453358", "color": "rgba(256, 230, 25, 1)", "y": 827.40620077376968, "x": 509.44389520540989, "border_width": 0, "id": "Mohamad61453358"}, {"node_shape": "dot", "degree": 2.5649493574615367, "title": "TacoLinz", "color": "rgba(256, 230, 25, 1)", "y": 335.53420405710352, "x": 365.03336039766043, "border_width": 0, "id": "TacoLinz"}, {"node_shape": "dot", "degree": -Infinity, "title": "Connie98461032", "color": "rgba(256, 230, 25, 1)", "y": 522.5680984167908, "x": 311.60438583109288, "border_width": 0, "id": "Connie98461032"}, {"node_shape": "dot", "degree": 13.759077763152092, "title": "Reince", "color": "rgba(256, 230, 25, 1)", "y": 0.80732430313966463, "x": 523.09735501771377, "border_width": 0, "id": "Reince"}, {"node_shape": "dot", "degree": 0.69314718055994529, "title": "RezaulHaque46", "color": "rgba(256, 230, 25, 1)", "y": 459.91692705171994, "x": 325.39718504978043, "border_width": 0, "id": "RezaulHaque46"}, {"node_shape": "dot", "degree": 10.264059891753556, "title": "freedomcaucus", "color": "rgba(256, 230, 25, 1)", "y": 918.65169676869368, "x": 773.95443873795239, "border_width": 0, "id": "freedomcaucus"}, {"node_shape": "dot", "degree": 6.5264948595707901, "title": "SaeidMsa", "color": "rgba(256, 230, 25, 1)", "y": 190.9872470601459, "x": 623.39607450249798, "border_width": 0, "id": "SaeidMsa"}, {"node_shape": "dot", "degree": 11.959513322367398, "title": "Scavino45", "color": "rgba(256, 230, 25, 1)", "y": 275.95482580088895, "x": 947.54111841864164, "border_width": 0, "id": "Scavino45"}, {"node_shape": "dot", "degree": -Infinity, "title": "devintila4", "color": "rgba(256, 230, 25, 1)", "y": 339.78939379816421, "x": 462.09332706870043, "border_width": 0, "id": "devintila4"}, {"node_shape": "dot", "degree": 5.2364419628299492, "title": "haito180", "color": "rgba(256, 230, 25, 1)", "y": 320.44047436531366, "x": 775.77046552955801, "border_width": 0, "id": "haito180"}, {"node_shape": "dot", "degree": 0.69314718055994529, "title": "MariaDo12223557", "color": "rgba(256, 230, 25, 1)", "y": 499.53294088020402, "x": 576.27518606731326, "border_width": 0, "id": "MariaDo12223557"}, {"node_shape": "dot", "degree": 0.0, "title": "Hurricane_Irma3", "color": "rgba(256, 230, 25, 1)", "y": 444.82109539006416, "x": 268.85111157921654, "border_width": 0, "id": "Hurricane_Irma3"}, {"node_shape": "dot", "degree": 9.15451048701 ...
